# %% [markdown]
# # DSA210 - 3D Printing Project
# ## ML Analysis with Hyperparameter Tuning
# GridSearchCV + Training/Validation/Test visualizations

# %%
# Install required libraries
# !pip install xgboost scikit-learn

# %%
# Step 1: Feature engineering and data augmentation
exec(open('enrich_data.py').read())

# %%
# Step 2: ML analysis with GridSearchCV hyperparameter tuning
exec(open('ml_analysis_v2.py').read())

# %%
# Step 3: Download output files
from google.colab import files
files.download('enriched_data.csv')
files.download('train_val_test_comparison.png')
files.download('learning_curves.png')
files.download('best_params_table.png')
files.download('actual_vs_predicted_all.png')
