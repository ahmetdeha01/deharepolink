# %%
# !pip install xgboost scikit-learn
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.30.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
exec(open('enrich_data.py').read())
# Out:
# Original data shape: (50, 12)
# After feature engineering: (50, 18)
# After augmentation:     (250, 18)
#
# ── Distribution check (mean should be similar) ──
#   roughness             original mean: 170.58  |  enriched mean: 170.86
#   tensile_strength      original mean: 20.08  |  enriched mean: 20.09
#   elongation            original mean: 1.67  |  enriched mean: 1.67
#
# New features added: heat_ratio, thermal_delta, volumetric_flow, infill_wall_ratio, material_pla, pattern_honeycomb
# Total columns: 18
#
# ✅ Saved: enriched_data.csv  (250 rows × 18 cols)

# %%
exec(open('ml_analysis.py').read())
# Out:
# Features (13): ['layer_height', 'wall_thickness', 'infill_density', 'nozzle_temperature', 'bed_temperature', 'print_speed', 'fan_speed', 'heat_ratio', 'thermal_delta', 'volumetric_flow', 'infill_wall_ratio', 'material_pla', 'pattern_honeycomb']
# Targets:  ['roughness', 'tensile_strength', 'elongation']
# Dataset:  250 rows
#
#
# ============================================================
#   TARGET: ROUGHNESS
# ============================================================
#   Model                      RMSE      MAE       R²    CV R²
#   ------------------------------------------------------
#   Linear Regression        29.741   22.105    0.915    0.914
#   Random Forest            12.268    6.836    0.985    0.986
#   XGBoost                   9.312      5.8    0.992    0.964
#   SVR                      43.006   31.531    0.821    0.827
#
# ============================================================
#   TARGET: TENSILE_STRENGTH
# ============================================================
#   Model                      RMSE      MAE       R²    CV R²
#   ------------------------------------------------------
#   Linear Regression         5.163     4.13    0.649    0.743
#   Random Forest             1.559    1.047    0.968    0.986
#   XGBoost                   1.369    0.913    0.975    0.943
#   SVR                       2.302    0.824     0.93     0.97
#
# ============================================================
#   TARGET: ELONGATION
# ============================================================
#   Model                      RMSE      MAE       R²    CV R²
#   ------------------------------------------------------
#   Linear Regression         0.361    0.299    0.762    0.786
#   Random Forest             0.182     0.12    0.939    0.977
#   XGBoost                   0.179    0.096    0.941    0.968
#   SVR                       0.085    0.077    0.987     0.99
#
# ✅ Saved: feature_importance.png
# ✅ Saved: model_comparison.png
# ✅ Saved: actual_vs_predicted.png
#
# 🎉 ML analysis complete!

# %%
from google.colab import files
files.download('feature_importance.png')
files.download('model_comparison.png')
files.download('actual_vs_predicted.png')

# %%
from google.colab import files
files.download('feature_importance.png')
files.download('model_comparison.png')
files.download('actual_vs_predicted.png')
files.download('enriched_data.csv')
